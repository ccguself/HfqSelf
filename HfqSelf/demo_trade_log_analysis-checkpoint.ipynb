# %%
import pandas as pd
import numpy as np
import os
from peewee import *

# %%
def fetch_data(beging_datetime="2021-01-17", end_datetime="2021-01-18", symbol="rb2105", db_path="D:\Trader\.vntrader\database.db"):
    db = SqliteDatabase(db_path)
    market_log = pd.read_sql("select * from dbtickdata where (symbol='%s') and Date(datetime) between '%s' and '%s'" %(symbol, beging_datetime, end_datetime), db, parse_dates="datetime")
    return market_log
temp_df = fetch_data()

# %%
temp_df.columns
# Out:
# Index(['id', 'symbol', 'exchange', 'datetime', 'name', 'volume',
#        'open_interest', 'last_price', 'last_volume', 'limit_up', 'limit_down',
#        'open_price', 'high_price', 'low_price', 'pre_close', 'bid_price_1',
#        'bid_price_2', 'bid_price_3', 'bid_price_4', 'bid_price_5',
#        'ask_price_1', 'ask_price_2', 'ask_price_3', 'ask_price_4',
#        'ask_price_5', 'bid_volume_1', 'bid_volume_2', 'bid_volume_3',
#        'bid_volume_4', 'bid_volume_5', 'ask_volume_1', 'ask_volume_2',
#        'ask_volume_3', 'ask_volume_4', 'ask_volume_5'],
#       dtype='object')

# %%
keep_columns = ["datetime", "last_price", "volume", "bid_price_1", "bid_volume_1", "ask_price_1", "ask_volume_1"]
df = temp_df[keep_columns]
df["datetime"] = df["datetime"]

# %%
df.values.shape
# Out:
# (25083, 7)

# %%
from prophet.predict import signal_output

# %%
model = signal_output()

# %%
class SingleCombinedLog:
    def __init__(self, raw_signal, df_predict_interval):
        self.raw_signal = raw_signal
        self.df_predict_interval = df_predict_interval
dict_long = {}  # datetime: SingleCombinedLog
dict_short = {} 
for i, timestamp_beging in enumerate(df["datetime"]):
    if (i > 2000) & ((i % 20) == 0):
        train_df = df.iloc[i-2000:i, :]

        train_df["datetime"] = train_df["datetime"].apply(lambda x:x.timestamp())
        raw_signals = model.get_output_list(train_df.values)
        print(timestamp_beging)
        for j, signal in enumerate(raw_signals):
            timestamp_end = timestamp_beging + datetime.timedelta(minutes=signal["duration_min"])
            df_predict = df.loc[(df["datetime"] > timestamp_beging) & (df["datetime"] < timestamp_end)]
            if signal["direction"] == "long":
                dict_long[timestamp] = SingleCombinedLog(signal, df_predict)
            elif signal["direction"] == "short":
                dict_short[timestamp] = SingleCombinedLog(signal, df_predict)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-a8484425c9a7> in <module>
#      10
#      11         train_df["datetime"] = train_df["datetime"].apply(lambda x:x.timestamp())
# ---> 12         raw_signals = model.get_output_list(train_df.values)
#      13         for j, signal in enumerate(raw_signals):
#      14             timestamp_end = timestamp_beging + datetime.timedelta(minutes=signal["duration_min"])
#
# d:\Code\hfq\HfqSelf\prophet\predict.py in get_output_list(self, data)
#      82     def get_output_list(self, data):
#      83         x = self.p.get_datax(data)
# ---> 84         return self.p.run(data, x, 1, 2, 2, 2) + self.p.run(data, x, 0, 2, 2, 2)
#
# d:\Code\hfq\HfqSelf\prophet\predict.py in run(self, data_org, x, d, tic, bound, intv, category)
#      51             args = args_cu
#      52             fcstnet = self.model_cu
# ---> 53         r = fcstnet.evaluate(x)
#      54
#      55         def idx(a):
#
# d:\Code\hfq\HfqSelf\prophet\forecast.py in evaluate(self, test_x)
#      70                 )
#      71             )
# ---> 72             y_pred = self.model(test_x, empty_y, is_training=False)
#      73         return y_pred.cpu().numpy()
#      74
#
# D:\anaconda\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# d:\Code\hfq\HfqSelf\prophet\model.py in forward(self, input, target, is_training)
#      39             next_cell_input = input
#      40             for i in range(self.out_seq_length//self.conv_list[k]):
# ---> 41                 hidden = F.relu(self.hidden_layer1_list[k][i](next_cell_input))
#      42                 hidden = F.relu(self.hidden_layer2_list[k](hidden))
#      43                 output = self.output_layer_list[k](hidden)
#
# D:\anaconda\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# D:\anaconda\lib\site-packages\torch\nn\modules\linear.py in forward(self, input)
#      91
#      92     def forward(self, input: Tensor) -> Tensor:
# ---> 93         return F.linear(input, self.weight, self.bias)
#      94
#      95     def extra_repr(self) -> str:
#
# D:\anaconda\lib\site-packages\torch\nn\functional.py in linear(input, weight, bias)
#    1688     if input.dim() == 2 and bias is not None:
#    1689         # fused op is marginally faster
# -> 1690         ret = torch.addmm(bias, input, weight.t())
#    1691     else:
#    1692         output = input.matmul(weight.t())
#
# KeyboardInterrupt:

# %%
import datetime
datetime.timedelta(minutes=2)
# Out:
# datetime.timedelta(seconds=120)
